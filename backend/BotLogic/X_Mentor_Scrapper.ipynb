# %%
pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.11-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2023.11.17)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.11

# %%
from ntscraper import Nitter
import pandas as pd

# %%
scraper = Nitter(0)
# Out:
# Testing instances: 100%|██████████| 32/32 [00:55<00:00,  1.73s/it]

# %%
tweets = scraper.get_tweets("kenya", mode = 'hashtag', number=200)
# Out:
# WARNING:root:Empty page on https://nitter.tux.pizza

# %%
final_tweets = []
for x in tweets['tweets']:
    data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
    final_tweets.append(data)

# %%
dat = pd.DataFrame(final_tweets, columns =['twitter_link','text','date','likes','comments'])

# %%
dat
# Out:
#                                          twitter_link  \
# 0   https://twitter.com/ChinatuObinna/status/17548...
# 1   https://twitter.com/bosuntijani/status/1622396...
# 2   https://twitter.com/MwangiMaina_/status/175489...
# 3   https://twitter.com/MariaSTsehai/status/175488...
# 4   https://twitter.com/IWPR/status/17548990505187...
# 5   https://twitter.com/ConcernUK/status/174500658...
# 6   https://twitter.com/cruzeirosafaris/status/175...
# 7   https://twitter.com/KOrnithologist/status/1754...
# 8   https://twitter.com/NutritionIntl/status/14645...
# 9   https://twitter.com/NewsIADN/status/1754527787...
# 10  https://twitter.com/Asmerom50875022/status/175...
# 11  https://twitter.com/elmi_abubakar/status/17548...
# 12  https://twitter.com/agmutambo/status/175489510...
# 13  https://twitter.com/debbiestrade/status/175489...
# 14  https://twitter.com/RenaissanceDam/status/1754...
# 15  https://twitter.com/TheGreatChange1/status/175...
# 16  https://twitter.com/AmbassadorEstif/status/175...
# 17  https://twitter.com/quebecsomali/status/175489...
# 18  https://twitter.com/MwanzoTv/status/1754804486...
# 19  https://twitter.com/wildpetalstours/status/175...
# 20  https://twitter.com/QGCanopy/status/1622566037...
# 21  https://twitter.com/consideredview/status/1754...
# 22  https://twitter.com/EcomnewsAfrique/status/175...
# 23  https://twitter.com/NatashaWanji/status/137437...
# 24  https://twitter.com/globalhad/status/175488931...
# 25  https://twitter.com/FeedtheFuture/status/17548...
# 26  https://twitter.com/Mohamud_1979/status/175488...
# 27  https://twitter.com/AmbHassanYassin/status/175...
# 28  https://twitter.com/MwanzoTvPlus/status/175487...
# 29  https://twitter.com/Theanatoliapost/status/175...
# 30  https://twitter.com/romainlecour/status/175481...
# 31  https://twitter.com/AfDB_Group/status/17544715...
# 32  https://twitter.com/AmicideiBambini/status/175...
#
#                                                  text  \
# 0   British #Government free your citizen mazi nna...
# 1   Where are the folks building next gen #edtech ...
# 2   During President Ruto's official visit to #Tok...
# 3   Nchi jirani 🇰🇪walipata mvua kubwa na mafuriko ...
# 4   NEW VACANCY – Remote post, applications from i...
# 5   Meet Charles Eris, our Senior Livelihoods Offi...
# 6   Book the Nairobi National Park Tour or call us...
# 7   The Rufous Naped Lark singing out loud #BirdsS...
# 8   In partnership with @MOH_Kenya and @NakuruCoun...
# 9   ICGS Varaha (Vikram-class OPV) is on a 3-day v...
# 10  ታሪኽ ጅግንነትን ዓወትን💪 ታሪኽ ሓቅን ርትዕን ዜጋታት🇪🇷  ይክኣሎ 👉Op...
# 11  Well done , The world should know #Somaliland ...
# 12  Everyone choose: #State visit, official visit,...
# 13  All investments are coming in, send a DM to st...
# 14  The Ethiopian Prime Minister Abiy Ahmed said i...
# 15  Thank you #Masai tribe from #KENYA celebration...
# 16  WHEN DID #ERITEREA SUCCESSFULLY PUT BACK A GEN...
# 17  Somali canadian Rapist #canada #Toronto #nairo...
# 18  #Kenya has signed two bilateral agreements wit...
# 19  🔗https://www.facebook.com/100063651216209/post...
# 20  Today would have been the 71st Anniversary of ...
# 21  Good to see the #activists from UK & #Kenya & ...
# 22  🌐🔋 @BasiGoKenya, acteur majeur du transport en...
# 23  Everything you need to know about Money Market...
# 24  Exciting news from Nairobi, Kenya! 🌍   Islamic...
# 25  📰 The first #FeedtheFuture newsletter of 2024 ...
# 26  Astaan been abuur ah, gaar  u ah Burcad Badeed...
# 27  Thank you #Masai tribe from #KENYA celebration...
# 28  Afisa Mkuu Mtendaji wa Kampuni ya Kuzalisha Um...
# 29  Kenya'daki "açlık tarikatı" lideri Mackenzie'y...
# 30  2nd Blog Post on #Kenya - Intervention in #Hai...
# 31  🇰🇪#Kenya’s Transmission Network Improvement Pr...
# 32  🇰🇪Negli ultimi tempi, Anastacia, non ha potuto...
#
#                           date  likes  comments
# 0   Feb 6, 2024 · 11:40 AM UTC     14         0
# 1   Feb 6, 2023 · 12:47 AM UTC    134        72
# 2    Feb 6, 2024 · 3:58 PM UTC      8         0
# 3    Feb 6, 2024 · 3:24 PM UTC     67        20
# 4    Feb 6, 2024 · 4:05 PM UTC      0         0
# 5   Jan 10, 2024 · 8:56 AM UTC     18         1
# 6    Feb 6, 2024 · 4:00 PM UTC      0         0
# 7    Feb 6, 2024 · 1:35 PM UTC     13         0
# 8   Nov 27, 2021 · 9:22 AM UTC     28         2
# 9    Feb 5, 2024 · 3:29 PM UTC    275         1
# 10  Feb 5, 2024 · 11:28 PM UTC      7         1
# 11  Feb 6, 2024 · 11:49 AM UTC     12         0
# 12   Feb 6, 2024 · 3:49 PM UTC      1         1
# 13   Feb 6, 2024 · 3:49 PM UTC      0         0
# 14  Feb 6, 2024 · 12:43 PM UTC     20         3
# 15  Feb 6, 2024 · 10:38 AM UTC      7         0
# 16   Feb 6, 2024 · 7:23 AM UTC     19         2
# 17   Feb 6, 2024 · 3:40 PM UTC      0         0
# 18   Feb 6, 2024 · 9:49 AM UTC      7         0
# 19   Feb 6, 2024 · 3:36 PM UTC      1         0
# 20  Feb 6, 2023 · 12:01 PM UTC    932         5
# 21   Feb 6, 2024 · 1:33 PM UTC      9         0
# 22   Feb 6, 2024 · 3:32 PM UTC      1         0
# 23  Mar 23, 2021 · 2:55 PM UTC    359        16
# 24   Feb 6, 2024 · 3:26 PM UTC      1         0
# 25  Feb 6, 2024 · 12:30 PM UTC      6         0
# 26   Feb 6, 2024 · 3:24 PM UTC      0         0
# 27  Feb 6, 2024 · 12:53 AM UTC     81         3
# 28   Feb 6, 2024 · 2:40 PM UTC     11         0
# 29   Feb 6, 2024 · 3:17 PM UTC      0         0
# 30  Feb 6, 2024 · 10:46 AM UTC      3         0
# 31  Feb 5, 2024 · 11:46 AM UTC     51         0
# 32   Feb 6, 2024 · 3:14 PM UTC      1         0

# %%
dat.to_csv("data")

# %%
tweets = scraper.get_profile_info("Joan Kabura")

# %%
tweets
# Out:
# {'image': 'https://pbs.twimg.com/profile_images/1409438356577173506/fMRwsn_s_400x400.jpg',
#  'name': 'joan kabura',
#  'username': '@joankabura',
#  'id': '',
#  'bio': 'I do me, Love myself, Belive in God, and love myself again',
#  'location': 'Nairobi/KENYA',
#  'website': '',
#  'joined': '3:42 PM - 6 Sep 2011',
#  'stats': {'tweets': 333,
#   'following': 71,
#   'followers': 34,
#   'likes': 25,
#   'media': 0}}

# %%
tweets['image']
# Out:
# 'https://pbs.twimg.com/profile_images/1409438356577173506/fMRwsn_s_400x400.jpg'

# %%
def get_tweets(name, modes, no):
    tweets = scraper.get_tweets(name, mode = modes, number=no)
    final_tweets = []
    for x in tweets['tweets']:
        data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
        final_tweets.append(data)
    dat= pd.DataFrame(final_tweets, columns =['twitter_link','text','date','likes','comments'])
    return dat

# %%
data = get_tweets('JoanKabura','user',6)

# %%
data
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/ShankiAustine/status/12515...
# 1  https://twitter.com/Fact/status/12518397139436...
# 2  https://twitter.com/Fact/status/12512281863540...
# 3  https://twitter.com/MwalimuRachel/status/12510...
# 4  https://twitter.com/joankabura/status/12507031...
# 5  https://twitter.com/CKirubi/status/11243505035...
#
#                                                 text  \
# 0  Guys, remember Xtian Dela was once a firm Chri...
# 1  Life is not about the people who act true to y...
# 2  Over-thinking ruins you, ruins the situation, ...
# 3                       Ain’t this just the truth. 💯
# 4                  It's a good day to be a good day❤
# 5  Getting a university degree does not equal to ...
#
#                           date  likes  comments
# 0   Apr 18, 2020 · 2:53 PM UTC   1026       114
# 1  Apr 19, 2020 · 11:47 AM UTC   1471        19
# 2   Apr 17, 2020 · 7:17 PM UTC   3118        29
# 3   Apr 17, 2020 · 9:51 AM UTC      4         0
# 4   Apr 16, 2020 · 8:30 AM UTC      1         0
# 5    May 3, 2019 · 4:30 PM UTC   1938       108

# %%
scraper.get_profile_info('Moraa')
# Out:
# {'image': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_400x400.png',
#  'name': 'moraa Ruby',
#  'username': '@moraa',
#  'id': '',
#  'bio': '',
#  'location': '',
#  'website': '',
#  'joined': '8:51 AM - 24 Nov 2008',
#  'stats': {'tweets': 18,
#   'following': 94,
#   'followers': 85,
#   'likes': 66,
#   'media': 0}}
